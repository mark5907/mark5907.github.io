# %% [markdown]
# # Haar transformation on financial data
# Use SPY's adj close as example

# %%
def haar_trans(s):
    s.

# %%
import data_util as du
spy = du.get_stk('INDEX_SPY')

# %%
s = spy['Adjusted Close']
s.plot(figsize=(8,4))
plt.title('SPY')
